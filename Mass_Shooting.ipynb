# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('/content/Mass shooting data.csv')

# %%
dataset
# Out:
#      Incident Date                 State City Or County  \
# 0        15-Apr-21  District of Columbia     Washington
# 1        15-Apr-21               Indiana   Indianapolis
# 2        15-Apr-21              Illinois        Chicago
# 3        15-Apr-21               Florida      Pensacola
# 4        13-Apr-21              Maryland      Baltimore
# ...            ...                   ...            ...
# 1995     20-Aug-16           Connecticut         Hamden
# 1996     20-Aug-16            Washington         Tacoma
# 1997     20-Aug-16               Alabama     Citronelle
# 1998     18-Aug-16           Connecticut      Waterbury
# 1999     17-Aug-16            California        Oakland
#
#                                  Address  # Killed  # Injured  #Total
# 0     1800 block of West Virginia Ave NE         0          4       4
# 1                        8951 Mirabel Rd         8          5      13
# 2              600 block of N Sawyer Ave         0          4       4
# ...

# %%
dataset.shape
# Out:
# (2000, 7)

# %%
dataset.head()
# Out:
#   Incident Date                 State City Or County  \
# 0     15-Apr-21  District of Columbia     Washington
# 1     15-Apr-21               Indiana   Indianapolis
# 2     15-Apr-21              Illinois        Chicago
# 3     15-Apr-21               Florida      Pensacola
# 4     13-Apr-21              Maryland      Baltimore
#
#                               Address  # Killed  # Injured  #Total
# 0  1800 block of West Virginia Ave NE         0          4       4
# 1                     8951 Mirabel Rd         8          5      13
# 2           600 block of N Sawyer Ave         0          4       4
# 3                      700 Truman Ave         0          6       6
# 4            2300 block of Hoffman St         0          4       4

# %%
dataset.tail()
# Out:
#      Incident Date        State City Or County                      Address  \
# 1995     20-Aug-16  Connecticut         Hamden              903 Dixwell Ave
# 1996     20-Aug-16   Washington         Tacoma  900 block of Pacific Avenue
# 1997     20-Aug-16      Alabama     Citronelle               Jim Platt Road
# 1998     18-Aug-16  Connecticut      Waterbury            402 E Main Street
# 1999     17-Aug-16   California        Oakland              Mandela Parkway
#
#       # Killed  # Injured  #Total
# 1995         0          4       4
# 1996         0          5       5
# 1997         5          0       5
# 1998         0          4       4
# 1999         0          4       4

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Incident Date   2000 non-null   object
#  1   State           2000 non-null   object
#  2   City Or County  2000 non-null   object
#  3   Address         1997 non-null   object
#  4   # Killed        2000 non-null   int64
#  5   # Injured       2000 non-null   int64
#  6   #Total          2000 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 109.5+ KB

# %%
dataset.describe()
# Out:
#           # Killed   # Injured       #Total
# count  2000.000000  2000.00000  2000.000000
# mean      1.051000     4.27500     5.326000
# std       2.106803    10.00187    11.341651
# min       0.000000     0.00000     4.000000
# 25%       0.000000     3.00000     4.000000
# 50%       1.000000     4.00000     4.000000
# 75%       1.000000     5.00000     5.000000
# max      59.000000   441.00000   500.000000

# %%
dataset.isnull().sum()
# Out:
# Incident Date     0
# State             0
# City Or County    0
# Address           3
# # Killed          0
# # Injured         0
# #Total            0
# dtype: int64

# %%
total_victims_state=dataset.groupby('State').sum()
print('Total Victims=', total_victims_state['#Total'].sum())
total_victims_state.sort_values(by='#Total', ascending= False)
# Out:
# Total Victims= 10652
#                       # Killed  # Injured  #Total
# State
# Illinois                   152        917    1069
# California                 214        755     969
# Texas                      229        525     754
# Florida                    134        515     649
# Nevada                      72        489     561
# Pennsylvania                83        412     495
# Louisiana                   84        379     463
# Ohio                        79        345     424
# New York                    42        368     410
# Missouri                    83        261     344
# Tennessee                   46        276     322
# Maryland                    55        249     304
# North Carolina              77        224     301
# Georgia                     62        235     297
# Alabama                     61        212     273
# New Jersey                  44        214     258
# South Carolina              51        200     251
# ...

# %%
total_victims_state.sort_values(by='#Total', ascending= False).head()
# Out:
#             # Killed  # Injured  #Total
# State
# Illinois         152        917    1069
# California       214        755     969
# Texas            229        525     754
# Florida          134        515     649
# Nevada            72        489     561

# %%
total_victims_state.sort_values(by='#Total', ascending= False).tail()
# Out:
#               # Killed  # Injured  #Total
# State
# Alaska               5          8      13
# Maine                7          2       9
# Idaho                2          3       5
# South Dakota         1          3       4
# Wyoming              2          2       4

# %%
plt.subplots(figsize=(15,6))
cr=total_victims_state['#Total'].sort_values(ascending= False)
ax=cr.plot.bar()
ax.set_xlabel('State')
ax.set_ylabel('Total Number = Dead + Injured')
ax.set_title('Statewise Total Reported Cases')
plt.show()
print(cr)
# Out:
# State
# Illinois                1069
# California               969
# Texas                    754
# Florida                  649
# Nevada                   561
# Pennsylvania             495
# Louisiana                463
# Ohio                     424
# New York                 410
# Missouri                 344
# Tennessee                322
# Maryland                 304
# North Carolina           301
# Georgia                  297
# Alabama                  273
# New Jersey               258
# South Carolina           251
# Michigan                 237
# Mississippi              234
# Virginia                 233
# Indiana                  199
# District of Columbia     181
# Arkansas                 159
# Colorado                 148
# Kentucky                 145
# Arizona                   99
# Wisconsin                 99
# Connecticut               98
# Washington                97
# Minnesota                 88
# Massachusetts             74
# New Mexico                68
# ...

# %%
Indiana_Victims=dataset[dataset['State']=='Indiana']
Indiana_Victims.head()
# Out:
#    Incident Date    State City Or County                     Address  \
# 1      15-Apr-21  Indiana   Indianapolis             8951 Mirabel Rd
# 53     15-Mar-21  Indiana   Indianapolis  2300 block of N Harding St
# 59     13-Mar-21  Indiana   Indianapolis  300 block of N Randolph St
# 74     28-Feb-21  Indiana   East Chicago          1205 W Chicago Ave
# 94     13-Feb-21  Indiana   Indianapolis  3800 block of N Sherman Dr
#
#     # Killed  # Injured  #Total
# 1          8          5      13
# 53         1          4       5
# 59         4          1       5
# 74         0          4       4
# 94         0          4       4

# %%
import squarify

p=dataset.groupby('State').sum().sort_values(by='#Total',ascending=False).head(15)
y=p['#Total']
plt.figure(figsize=(12,6))
squarify.plot(y,label=list(zip(p.index,p['#Total'])),alpha=.6,pad=False, color=plt.cm.magma(np.linspace(0,1,15)))
plt.axis('off')
plt.title('Tree Map for Top Crime', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Tree Map for Top Crime')

# %%
dataset['Incident date']=pd.to_datetime(dataset['Incident Date'])
dataset['Year']=dataset['Incident Date'].dt.year
dataset['Year'].value_counts().plot.pie(figsize=(15,8))
plt.title('Crime Count each year',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Crime Count each year')

# %%
dataset['Month']=dataset['Incident date'].dt.month
sns.countplot(dataset['Month'],palette='autumn')
plt.title('Crimes in each Month', fontsize=12)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Crimes in each Month')

# %%
plt.figure(figsize=(30,6))
sns.boxplot(x='State',y='#Total',data=dataset)
plt.ylim(0,20)
plt.title('Crime Distribution')
# Out:
# Text(0.5, 1.0, 'Crime Distribution')

# %%
plt.figure(figsize=(30,6))
sns.scatterplot(x='State',y='#Total',data=dataset)
plt.ylim(0,30)
# Out:
# (0.0, 30.0)
